# %% [markdown]
# ## Weather Web Scraper
# ### by Kola Ademola.

# %%
#import neccesary libraries

import pandas as pd
import numpy as np
from bs4 import BeautifulSoup as bs
import requests as rq
from datetime import datetime

# %%
#load dataset
countries = pd.read_csv('west_africa.csv')

#view dataset
countries
# Out:
#           country       capital
# 0           Benin    Porto-Novo
# 1    Burkina-Faso   Ouagadougou
# 2      Cape-Verde         Praia
# 3    Cote-Divoire  Yamoussoukro
# 4          Gambia        Banjul
# 5           Ghana         Accra
# 6          Guinea       Conakry
# 7   Guinea-Bissau        Bissau
# 8         Liberia      Monrovia
# 9            Mali        Bamako
# 10     Mauritania    Nouakchott
# 11          Niger        Niamey
# 12        Nigeria         Abuja
# 13        Senegal         Dakar
# 14   Sierra-Leone      Freetown
# 15           Togo          Lome

# %%
#create empty lists to hold scraped data
weathers = []
temps = []
location = []

#loop through the countries and get their weather data
for index, row in countries.iterrows():
    country = row['country']
    capital = row['capital']
        
    url = 'https://www.timeanddate.com/weather/{}/{}'.format(country, capital)
    page = rq.get(url)
    
    soup = bs(page.content, 'html.parser')
    
    temp = soup.find('div', class_ = 'h2')
    
    weather = soup.find('p')
    
    if  weather is not None and temp is not None:
        location.append(country)
        weathers.append(weather.text)
        temps.append(temp.text)
    else:
        temps.append("N/A")
        location.append(country)
        weathers.append("N/A")

# %%
# get current date
current_date = datetime.now().date()

#format date from string to correct data type
formatted_date = current_date.strftime('%Y-%m-%d')

#load and fill dataframe with the data
data = {'Country': location, 'Current_Weather': weathers, 'Current_Temperature(F)': temps, 'Date' : formatted_date}

#create dataframe to hold the data
df = pd.DataFrame(data)

#view weather scraped data
df
# Out:
#           Country    Current_Weather Current_Temperature(F)        Date
# 0           Benin  Scattered clouds.                  90ʡF  2023-04-08
# 1    Burkina-Faso              Haze.                  84ʡF  2023-04-08
# 2      Cape-Verde  Scattered clouds.                  78ʡF  2023-04-08
# 3    Cote-Divoire          Overcast.                  87ʡF  2023-04-08
# 4          Gambia             Sunny.                  88ʡF  2023-04-08
# 5           Ghana  Scattered clouds.                  90ʡF  2023-04-08
# 6          Guinea              Haze.                  93ʡF  2023-04-08
# 7   Guinea-Bissau             Clear.                  99ʡF  2023-04-08
# 8         Liberia      Partly sunny.                  90ʡF  2023-04-08
# 9            Mali    Passing clouds.                  97ʡF  2023-04-08
# 10     Mauritania      Partly sunny.                  91ʡF  2023-04-08
# 11          Niger             Sunny.                 108ʡF  2023-04-08
# 12        Nigeria          Overcast.                  97ʡF  2023-04-08
# 13        Senegal             Sunny.                  77ʡF  2023-04-08
# 14   Sierra-Leone    Passing clouds.                  84ʡF  2023-04-08
# 15           Togo    Passing clouds.                  91ʡF  2023-04-08

# %% [markdown]
# * The temperature column will need to be formatted / cleaned to hold just the numeric value.

# %%
#duplicating original dataset before cleaning

weather_df = df.copy()

# %%
#removing the "degree" from the temperature column

temp = weather_df['Current_Temperature(F)'].str.split(expand = True)

#assign the temperatures to the main dataset
weather_df['Current_Temperature(F)'] = temp[0].astype(int)

#change the Date column to the right data type
weather_df['Date'] = pd.to_datetime(weather_df['Date'], format='%Y-%m-%d')

#view data
weather_df
# Out:
#           Country    Current_Weather  Current_Temperature(F)       Date
# 0           Benin  Scattered clouds.                      90 2023-04-08
# 1    Burkina-Faso              Haze.                      84 2023-04-08
# 2      Cape-Verde  Scattered clouds.                      78 2023-04-08
# 3    Cote-Divoire          Overcast.                      87 2023-04-08
# 4          Gambia             Sunny.                      88 2023-04-08
# 5           Ghana  Scattered clouds.                      90 2023-04-08
# 6          Guinea              Haze.                      93 2023-04-08
# 7   Guinea-Bissau             Clear.                      99 2023-04-08
# 8         Liberia      Partly sunny.                      90 2023-04-08
# 9            Mali    Passing clouds.                      97 2023-04-08
# 10     Mauritania      Partly sunny.                      91 2023-04-08
# 11          Niger             Sunny.                     108 2023-04-08
# 12        Nigeria          Overcast.                      97 2023-04-08
# 13        Senegal             Sunny.                      77 2023-04-08
# 14   Sierra-Leone    Passing clouds.                      84 2023-04-08
# 15           Togo    Passing clouds.                      91 2023-04-08

# %%
#check data types
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 16 non-null     object
#  1   Current_Weather         16 non-null     object
#  2   Current_Temperature(F)  16 non-null     int64
#  3   Date                    16 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 640.0+ bytes

# %%
#saving data to csv file for the first run of scraping
#weather_df.to_csv('west_african_weather.csv', index = False)

# %%
# load the existing weather DataFrame
existing_weather_df = pd.read_csv('west_african_weather.csv', parse_dates = ['Date'])

#format current date to be used in if condition to check if data already exist for current date
formatted_date = pd.to_datetime(formatted_date, format = '%Y-%m-%d')

# Check if date already exists in DataFrame
if formatted_date in existing_weather_df['Date'].values:
    combined_weather_df = existing_weather_df
else:
    # concatenate the new DataFrame with the existing DataFrame
    combined_weather_df = pd.concat([existing_weather_df, weather_df], ignore_index = True)

#change the Date column to the right data type
combined_weather_df['Date'] = pd.to_datetime(combined_weather_df['Date'])

#confirm new data
combined_weather_df
# Out:
#          Country                 Current_Weather  Current_Temperature(F)
# 0          Benin  Thunderstorms. Passing clouds.                      81  \
# 1   Burkina-Faso               Scattered clouds.                      88
# 2   Cote-Divoire                 Passing clouds.                      77
# 3     Cape-Verde                 Passing clouds.                      73
# 4         Gambia                          Clear.                      75
# ..           ...                             ...                     ...
# 59         Niger                          Clear.                     102
# 60       Nigeria                       Overcast.                      89
# 61       Senegal                 Passing clouds.                      75
# 62  Sierra-Leone                          Clear.                      82
# 63          Togo                 Passing clouds.                      90
#
#          Date
# 0  2023-04-04
# 1  2023-04-04
# 2  2023-04-04
# 3  2023-04-04
# 4  2023-04-04
# ..        ...
# 59 2023-04-08
# 60 2023-04-08
# 61 2023-04-08
# 62 2023-04-08
# 63 2023-04-08
#
# [64 rows x 4 columns]

# %%
#check data types
combined_weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 64 non-null     object
#  1   Current_Weather         64 non-null     object
#  2   Current_Temperature(F)  64 non-null     int64
#  3   Date                    64 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 2.1+ KB

# %%
# save the combined DataFrame to a CSV file
combined_weather_df.to_csv('west_african_weather.csv', index = False)
